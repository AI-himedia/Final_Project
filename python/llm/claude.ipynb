# %%
from pathlib import Path
from dotenv import load_dotenv

# %%
env_path = Path('.env')  # 실제 .env 파일 경로로 변경
load_dotenv(dotenv_path=env_path, override=True)
# Out:
# True

# %%
from langchain_teddynote import logging

# 프로젝트 이름을 입력합니다.
logging.langsmith("test_0327")

import os

print(os.getenv("LANGSMITH_TRACING"))       # 'true' 출력 확인
print(os.getenv("LANGCHAIN_TRACING_V2"))   # 'true' 출력 확인
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# test_0327
# true
# true

# %%
url = "https://api.anthropic.com/v1/messages"

role = '어머니'
tone = '반말, 다정한'
user = '현지(여자)'

# %%
# !pip3 install langchain_anthropic

# %%
import requests
from langchain_anthropic import ChatAnthropic
from langchain.chains import LLMChain
from langchain.prompts import ChatPromptTemplate
# from langchain.llms import LLM

llm = ChatAnthropic(
                    model="claude-3-sonnet-20240229", 
                    max_tokens=300, temperature=0.5,
                    anthropic_api_key=os.getenv("CLAUDE_KEY"),
                    )
# 프롬프트 템플릿 생성 -> ChatPromptTemplate은 f스트링 사용하지 않아도 된다고함. {}만 사용
prompt = ChatPromptTemplate.from_messages([
                                            ("system", 
                                                "당신은 돌아가신 {user}의 {role} 역할을 맡고 있습니다. 당신은 {user}를 공주라고 부릅니다. "
                                                "{user}와 대화할 때는 따뜻하고 사랑이 가득한 말투로 대화하세요. "
                                                "응답은 간결하고 최대 300글자로 작성하며, 정확한 한국어로 작성하세요. "
                                                "대화를 끝내는 듯한 말투를 피하고, 문장의 끝맺음을 정확히 해주세요. "
                                                "사용자가 제공한 정보만 바탕으로 응답하며, 새로운 추억이나 사실을 생성하지 마세요."
                                                ),
                                            ("user", "{user_input}")
])

# %%
# LLMChain 생성
chain = LLMChain(llm=llm, prompt=prompt)

# 체인 실행
response = chain.run(user=user, role=role, user_input="엄마 잘 지내지? 나는 오늘 유진이랑 할머니댁에 다녀왔어. 유진이가 엄마 얘기를 많이 했어. 엄마, 오늘따라 더 보고싶다")

print(response)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[14], line 5
#       2 chain = LLMChain(llm=llm, prompt=prompt)
#       4 # 체인 실행
# ----> 5 response = chain.run(user=user, role=role, user_input="엄마 잘 지내지? 나는 오늘 유진이랑 할머니댁에 다녀왔어. 유진이가 엄마 얘기를 많이 했어. 엄마, 오늘따라 더 보고싶다")
#       7 print(response)
#
# File /opt/anaconda3/envs/proj2/lib/python3.12/site-packages/langchain_core/_api/deprecation.py:181, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     179     warned = True
#     180     emit_warning()
# --> 181 return wrapped(*args, **kwargs)
#
# File /opt/anaconda3/envs/proj2/lib/python3.12/site-packages/langchain/chains/base.py:611, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     606     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     607         _output_key
#     608     ]
# ...
